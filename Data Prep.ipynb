# %%
# GENERAL UTILITIES
import os
import pywt
import numpy as np
import pandas as pd
from glob import glob
import seaborn as sns
from  tqdm.notebook import tqdm
from matplotlib import pyplot as plt
# %matplotlib inline

# MODEL DEVELOPMENT DEPENDENCIES


from sklearn.model_selection import KFold, StratifiedKFold
from sklearn.multioutput import MultiOutputRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error
from sklearn import preprocessing
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
# !wget "https://s3.waw2-1.cloudferro.com/swift/v1/AUTH_afccea586afd4ef3bb11fe37dd1ddfbf/Download_KPLabs_Chellenge/test_data.zip"
# !wget "https://s3.waw2-1.cloudferro.com/swift/v1/AUTH_afccea586afd4ef3bb11fe37dd1ddfbf/Download_KPLabs_Chellenge/train_data.zip"
# !unzip test_data.zip
# !unzip train_data.zip
# Out:
# --2023-11-09 19:08:47--  https://s3.waw2-1.cloudferro.com/swift/v1/AUTH_afccea586afd4ef3bb11fe37dd1ddfbf/Download_KPLabs_Chellenge/test_data.zip
# Resolving s3.waw2-1.cloudferro.com (s3.waw2-1.cloudferro.com)... 185.48.234.249
# Connecting to s3.waw2-1.cloudferro.com (s3.waw2-1.cloudferro.com)|185.48.234.249|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1314110621 (1.2G) [application/zip]
# Saving to: ‘test_data.zip’
#
# test_data.zip       100%[===================>]   1.22G  31.9MB/s    in 41s
#
# 2023-11-09 19:09:28 (30.8 MB/s) - ‘test_data.zip’ saved [1314110621/1314110621]
#
# --2023-11-09 19:09:29--  https://s3.waw2-1.cloudferro.com/swift/v1/AUTH_afccea586afd4ef3bb11fe37dd1ddfbf/Download_KPLabs_Chellenge/train_data.zip
# Resolving s3.waw2-1.cloudferro.com (s3.waw2-1.cloudferro.com)... 185.48.234.249
# Connecting to s3.waw2-1.cloudferro.com (s3.waw2-1.cloudferro.com)|185.48.234.249|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1970208481 (1.8G) [application/zip]
# Saving to: ‘train_data.zip’
#
# train_data.zip      100%[===================>]   1.83G  31.9MB/s    in 61s
#
# 2023-11-09 19:10:31 (30.8 MB/s) - ‘train_data.zip’ saved [1970208481/1970208481]
#
# Archive:  test_data.zip
#    creating: test_data/
#   inflating: test_data/0.npz
#   inflating: test_data/1.npz
#   inflating: test_data/10.npz
#   inflating: test_data/100.npz
#   inflating: test_data/1000.npz
#   inflating: test_data/1001.npz
#   inflating: test_data/1002.npz
#   inflating: test_data/1003.npz
#   inflating: test_data/1004.npz
#   inflating: test_data/1005.npz
#   inflating: test_data/1006.npz
#   inflating: test_data/1007.npz
#   inflating: test_data/1008.npz
#   inflating: test_data/1009.npz
#   inflating: test_data/101.npz
#   inflating: test_data/1010.npz
#   inflating: test_data/1011.npz
#   inflating: test_data/1012.npz
#   inflating: test_data/1013.npz
#   inflating: test_data/1014.npz
#   inflating: test_data/1015.npz
#   inflating: test_data/1016.npz
#   inflating: test_data/1017.npz
#   inflating: test_data/1018.npz
#   inflating: test_data/1019.npz
#   inflating: test_data/102.npz
#   inflating: test_data/1020.npz
#   inflating: test_data/1021.npz
#   inflating: test_data/1022.npz
#   inflating: test_data/1023.npz
#   inflating: test_data/1024.npz
#   inflating: test_data/1025.npz
#   inflating: test_data/1026.npz
#   inflating: test_data/1027.npz
#   inflating: test_data/1028.npz
#   inflating: test_data/1029.npz
#   inflating: test_data/103.npz
#   inflating: test_data/1030.npz
#   inflating: test_data/1031.npz
#   inflating: test_data/1032.npz
#   inflating: test_data/1033.npz
#   inflating: test_data/1034.npz
#   inflating: test_data/1035.npz
#   inflating: test_data/1036.npz
#   inflating: test_data/1037.npz
#   inflating: test_data/1038.npz
#   inflating: test_data/1039.npz
#   inflating: test_data/104.npz
#   inflating: test_data/1040.npz
#   inflating: test_data/1041.npz
#   inflating: test_data/1042.npz
#   inflating: test_data/1043.npz
#   inflating: test_data/1044.npz
#   inflating: test_data/1045.npz
#   inflating: test_data/1046.npz
#   inflating: test_data/1047.npz
#   inflating: test_data/1048.npz
#   inflating: test_data/1049.npz
#   inflating: test_data/105.npz
#   inflating: test_data/1050.npz
#   inflating: test_data/1051.npz
#   inflating: test_data/1052.npz
#   inflating: test_data/1053.npz
#   inflating: test_data/1054.npz
#   inflating: test_data/1055.npz
#   inflating: test_data/1056.npz
#   inflating: test_data/1057.npz
#   inflating: test_data/1058.npz
#   inflating: test_data/1059.npz
#   inflating: test_data/106.npz
#   inflating: test_data/1060.npz
#   inflating: test_data/1061.npz
#   inflating: test_data/1062.npz
#   inflating: test_data/1063.npz
#   inflating: test_data/1064.npz
#   inflating: test_data/1065.npz
#   inflating: test_data/1066.npz
#   inflating: test_data/1067.npz
#   inflating: test_data/1068.npz
#   inflating: test_data/1069.npz
#   inflating: test_data/107.npz
#   inflating: test_data/1070.npz
#   inflating: test_data/1071.npz
#   inflating: test_data/1072.npz
#   inflating: test_data/1073.npz
#   inflating: test_data/1074.npz
#   inflating: test_data/1075.npz
#   inflating: test_data/1076.npz
#   inflating: test_data/1077.npz
#   inflating: test_data/1078.npz
#   inflating: test_data/1079.npz
#   inflating: test_data/108.npz
#   inflating: test_data/1080.npz
#   inflating: test_data/1081.npz
#   inflating: test_data/1082.npz
#   inflating: test_data/1083.npz
#   inflating: test_data/1084.npz
#   inflating: test_data/1085.npz
#   inflating: test_data/1086.npz
#   inflating: test_data/1087.npz
#   inflating: test_data/1088.npz
#   inflating: test_data/1089.npz
#   inflating: test_data/109.npz
#   inflating: test_data/1090.npz
#   inflating: test_data/1091.npz
#   inflating: test_data/1092.npz
#   inflating: test_data/1093.npz
#   inflating: test_data/1094.npz
#   inflating: test_data/1095.npz
#   inflating: test_data/1096.npz
#   inflating: test_data/1097.npz
#   inflating: test_data/1098.npz
#   inflating: test_data/1099.npz
#   inflating: test_data/11.npz
#   inflating: test_data/110.npz
#   inflating: test_data/1100.npz
#   inflating: test_data/1101.npz
#   inflating: test_data/1102.npz
#   inflating: test_data/1103.npz
#   inflating: test_data/1104.npz
#   inflating: test_data/1105.npz
#   inflating: test_data/1106.npz
#   inflating: test_data/1107.npz
#   inflating: test_data/1108.npz
#   inflating: test_data/1109.npz
#   inflating: test_data/111.npz
#   inflating: test_data/1110.npz
#   inflating: test_data/1111.npz
#   inflating: test_data/1112.npz
#   inflating: test_data/1113.npz
#   inflating: test_data/1114.npz
#   inflating: test_data/1115.npz
#   inflating: test_data/1116.npz
#   inflating: test_data/1117.npz
#   inflating: test_data/1118.npz
#   inflating: test_data/1119.npz
#   inflating: test_data/112.npz
#   inflating: test_data/1120.npz
#   inflating: test_data/1121.npz
#   inflating: test_data/1122.npz
#   inflating: test_data/1123.npz
#   inflating: test_data/1124.npz
#   inflating: test_data/1125.npz
#   inflating: test_data/1126.npz
#   inflating: test_data/1127.npz
#   inflating: test_data/1128.npz
#   inflating: test_data/1129.npz
#   inflating: test_data/113.npz
#   inflating: test_data/1130.npz
#   inflating: test_data/1131.npz
#   inflating: test_data/1132.npz
#   inflating: test_data/1133.npz
#   inflating: test_data/1134.npz
#   inflating: test_data/1135.npz
#   inflating: test_data/1136.npz
#   inflating: test_data/1137.npz
#   inflating: test_data/1138.npz
#   inflating: test_data/1139.npz
#   inflating: test_data/114.npz
#   inflating: test_data/1140.npz
#   inflating: test_data/1141.npz
#   inflating: test_data/1142.npz
#   inflating: test_data/1143.npz
#   inflating: test_data/1144.npz
#   inflating: test_data/1145.npz
#   inflating: test_data/1146.npz
#   inflating: test_data/1147.npz
#   inflating: test_data/1148.npz
#   inflating: test_data/1149.npz
#   inflating: test_data/115.npz
#   inflating: test_data/1150.npz
#   inflating: test_data/1151.npz
#   inflating: test_data/1152.npz
#   inflating: test_data/1153.npz
#   inflating: test_data/116.npz
#   inflating: test_data/117.npz
#   inflating: test_data/118.npz
#   inflating: test_data/119.npz
#   inflating: test_data/12.npz
#   inflating: test_data/120.npz
#   inflating: test_data/121.npz
#   inflating: test_data/122.npz
#   inflating: test_data/123.npz
#   inflating: test_data/124.npz
#   inflating: test_data/125.npz
#   inflating: test_data/126.npz
#   inflating: test_data/127.npz
#   inflating: test_data/128.npz
#   inflating: test_data/129.npz
#   inflating: test_data/13.npz
#   inflating: test_data/130.npz
#   inflating: test_data/131.npz
#   inflating: test_data/132.npz
#   inflating: test_data/133.npz
#   inflating: test_data/134.npz
#   inflating: test_data/135.npz
#   inflating: test_data/136.npz
#   inflating: test_data/137.npz
#   inflating: test_data/138.npz
#   inflating: test_data/139.npz
#   inflating: test_data/14.npz
#   inflating: test_data/140.npz
#   inflating: test_data/141.npz
#   inflating: test_data/142.npz
#   inflating: test_data/143.npz
#   inflating: test_data/144.npz
#   inflating: test_data/145.npz
#   inflating: test_data/146.npz
#   inflating: test_data/147.npz
#   inflating: test_data/148.npz
#   inflating: test_data/149.npz
#   inflating: test_data/15.npz
#   inflating: test_data/150.npz
#   inflating: test_data/151.npz
#   inflating: test_data/152.npz
#   inflating: test_data/153.npz
#   inflating: test_data/154.npz
#   inflating: test_data/155.npz
#   inflating: test_data/156.npz
#   inflating: test_data/157.npz
#   inflating: test_data/158.npz
#   inflating: test_data/159.npz
#   inflating: test_data/16.npz
#   inflating: test_data/160.npz
#   inflating: test_data/161.npz
#   inflating: test_data/162.npz
#   inflating: test_data/163.npz
#   inflating: test_data/164.npz
#   inflating: test_data/165.npz
#   inflating: test_data/166.npz
#   inflating: test_data/167.npz
#   inflating: test_data/168.npz
#   inflating: test_data/169.npz
#   inflating: test_data/17.npz
#   inflating: test_data/170.npz
#   inflating: test_data/171.npz
#   inflating: test_data/172.npz
#   inflating: test_data/173.npz
#   inflating: test_data/174.npz
#   inflating: test_data/175.npz
#   inflating: test_data/176.npz
#   inflating: test_data/177.npz
#   inflating: test_data/178.npz
#   inflating: test_data/179.npz
#   inflating: test_data/18.npz
#   inflating: test_data/180.npz
#   inflating: test_data/181.npz
#   inflating: test_data/182.npz
#   inflating: test_data/183.npz
#   inflating: test_data/184.npz
#   inflating: test_data/185.npz
#   inflating: test_data/186.npz
#   inflating: test_data/187.npz
#   inflating: test_data/188.npz
#   inflating: test_data/189.npz
#   inflating: test_data/19.npz
#   inflating: test_data/190.npz
#   inflating: test_data/191.npz
#   inflating: test_data/192.npz
#   inflating: test_data/193.npz
#   inflating: test_data/194.npz
#   inflating: test_data/195.npz
#   inflating: test_data/196.npz
#   inflating: test_data/197.npz
#   inflating: test_data/198.npz
#   inflating: test_data/199.npz
#   inflating: test_data/2.npz
#   inflating: test_data/20.npz
#   inflating: test_data/200.npz
#   inflating: test_data/201.npz
#   inflating: test_data/202.npz
#   inflating: test_data/203.npz
#   inflating: test_data/204.npz
#   inflating: test_data/205.npz
#   inflating: test_data/206.npz
#   inflating: test_data/207.npz
#   inflating: test_data/208.npz
#   inflating: test_data/209.npz
#   inflating: test_data/21.npz
#   inflating: test_data/210.npz
#   inflating: test_data/211.npz
#   inflating: test_data/212.npz
#   inflating: test_data/213.npz
#   inflating: test_data/214.npz
#   inflating: test_data/215.npz
#   inflating: test_data/216.npz
#   inflating: test_data/217.npz
#   inflating: test_data/218.npz
#   inflating: test_data/219.npz
#   inflating: test_data/22.npz
#   inflating: test_data/220.npz
#   inflating: test_data/221.npz
#   inflating: test_data/222.npz
#   inflating: test_data/223.npz
#   inflating: test_data/224.npz
#   inflating: test_data/225.npz
#   inflating: test_data/226.npz
#   inflating: test_data/227.npz
#   inflating: test_data/228.npz
#   inflating: test_data/229.npz
#   inflating: test_data/23.npz
#   inflating: test_data/230.npz
#   inflating: test_data/231.npz
#   inflating: test_data/232.npz
#   inflating: test_data/233.npz
#   inflating: test_data/234.npz
#   inflating: test_data/235.npz
#   inflating: test_data/236.npz
#   inflating: test_data/237.npz
#   inflating: test_data/238.npz
#   inflating: test_data/239.npz
#   inflating: test_data/24.npz
#   inflating: test_data/240.npz
#   inflating: test_data/241.npz
#   inflating: test_data/242.npz
#   inflating: test_data/243.npz
#   inflating: test_data/244.npz
#   inflating: test_data/245.npz
#   inflating: test_data/246.npz
#   inflating: test_data/247.npz
#   inflating: test_data/248.npz
#   inflating: test_data/249.npz
#   inflating: test_data/25.npz
#   inflating: test_data/250.npz
#   inflating: test_data/251.npz
#   inflating: test_data/252.npz
#   inflating: test_data/253.npz
#   inflating: test_data/254.npz
#   inflating: test_data/255.npz
#   inflating: test_data/256.npz
#   inflating: test_data/257.npz
#   inflating: test_data/258.npz
#   inflating: test_data/259.npz
#   inflating: test_data/26.npz
#   inflating: test_data/260.npz
#   inflating: test_data/261.npz
#   inflating: test_data/262.npz
#   inflating: test_data/263.npz
#   inflating: test_data/264.npz
#   inflating: test_data/265.npz
#   inflating: test_data/266.npz
#   inflating: test_data/267.npz
#   inflating: test_data/268.npz
#   inflating: test_data/269.npz
#   inflating: test_data/27.npz
#   inflating: test_data/270.npz
#   inflating: test_data/271.npz
#   inflating: test_data/272.npz
#   inflating: test_data/273.npz
#   inflating: test_data/274.npz
#   inflating: test_data/275.npz
#   inflating: test_data/276.npz
#   inflating: test_data/277.npz
#   inflating: test_data/278.npz
#   inflating: test_data/279.npz
#   inflating: test_data/28.npz
#   inflating: test_data/280.npz
#   inflating: test_data/281.npz
#   inflating: test_data/282.npz
#   inflating: test_data/283.npz
#   inflating: test_data/284.npz
#   inflating: test_data/285.npz
#   inflating: test_data/286.npz
#   inflating: test_data/287.npz
#   inflating: test_data/288.npz
#   inflating: test_data/289.npz
#   inflating: test_data/29.npz
#   inflating: test_data/290.npz
#   inflating: test_data/291.npz
#   inflating: test_data/292.npz
#   inflating: test_data/293.npz
#   inflating: test_data/294.npz
#   inflating: test_data/295.npz
#   inflating: test_data/296.npz
#   inflating: test_data/297.npz
#   inflating: test_data/298.npz
#   inflating: test_data/299.npz
#   inflating: test_data/3.npz
#   inflating: test_data/30.npz
#   inflating: test_data/300.npz
#   inflating: test_data/301.npz
#   inflating: test_data/302.npz
#   inflating: test_data/303.npz
#   inflating: test_data/304.npz
#   inflating: test_data/305.npz
#   inflating: test_data/306.npz
#   inflating: test_data/307.npz
#   inflating: test_data/308.npz
#   inflating: test_data/309.npz
#   inflating: test_data/31.npz
#   inflating: test_data/310.npz
#   inflating: test_data/311.npz
#   inflating: test_data/312.npz
#   inflating: test_data/313.npz
#   inflating: test_data/314.npz
#   inflating: test_data/315.npz
#   inflating: test_data/316.npz
#   inflating: test_data/317.npz
#   inflating: test_data/318.npz
#   inflating: test_data/319.npz
#   inflating: test_data/32.npz
#   inflating: test_data/320.npz
#   inflating: test_data/321.npz
#   inflating: test_data/322.npz
#   inflating: test_data/323.npz
#   inflating: test_data/324.npz
#   inflating: test_data/325.npz
#   inflating: test_data/326.npz
#   inflating: test_data/327.npz
#   inflating: test_data/328.npz
#   inflating: test_data/329.npz
#   inflating: test_data/33.npz
#   inflating: test_data/330.npz
#   inflating: test_data/331.npz
#   inflating: test_data/332.npz
#   inflating: test_data/333.npz
#   inflating: test_data/334.npz
#   inflating: test_data/335.npz
#   inflating: test_data/336.npz
#   inflating: test_data/337.npz
#   inflating: test_data/338.npz
#   inflating: test_data/339.npz
#   inflating: test_data/34.npz
#   inflating: test_data/340.npz
#   inflating: test_data/341.npz
#   inflating: test_data/342.npz
#   inflating: test_data/343.npz
#   inflating: test_data/344.npz
#   inflating: test_data/345.npz
#   inflating: test_data/346.npz
#   inflating: test_data/347.npz
#   inflating: test_data/348.npz
#   inflating: test_data/349.npz
#   inflating: test_data/35.npz
#   inflating: test_data/350.npz
#   inflating: test_data/351.npz
#   inflating: test_data/352.npz
#   inflating: test_data/353.npz
#   inflating: test_data/354.npz
#   inflating: test_data/355.npz
#   inflating: test_data/356.npz
#   inflating: test_data/357.npz
#   inflating: test_data/358.npz
#   inflating: test_data/359.npz
#   inflating: test_data/36.npz
#   inflating: test_data/360.npz
#   inflating: test_data/361.npz
#   inflating: test_data/362.npz
#   inflating: test_data/363.npz
#   inflating: test_data/364.npz
#   inflating: test_data/365.npz
#   inflating: test_data/366.npz
#   inflating: test_data/367.npz
#   inflating: test_data/368.npz
#   inflating: test_data/369.npz
#   inflating: test_data/37.npz
#   inflating: test_data/370.npz
#   inflating: test_data/371.npz
#   inflating: test_data/372.npz
#   inflating: test_data/373.npz
#   inflating: test_data/374.npz
#   inflating: test_data/375.npz
#   inflating: test_data/376.npz
#   inflating: test_data/377.npz
#   inflating: test_data/378.npz
#   inflating: test_data/379.npz
#   inflating: test_data/38.npz
#   inflating: test_data/380.npz
#   inflating: test_data/381.npz
#   inflating: test_data/382.npz
#   inflating: test_data/383.npz
#   inflating: test_data/384.npz
#   inflating: test_data/385.npz
#   inflating: test_data/386.npz
#   inflating: test_data/387.npz
#   inflating: test_data/388.npz
#   inflating: test_data/389.npz
#   inflating: test_data/39.npz
#   inflating: test_data/390.npz
#   inflating: test_data/391.npz
#   inflating: test_data/392.npz
#   inflating: test_data/393.npz
#   inflating: test_data/394.npz
#   inflating: test_data/395.npz
#   inflating: test_data/396.npz
#   inflating: test_data/397.npz
#   inflating: test_data/398.npz
#   inflating: test_data/399.npz
#   inflating: test_data/4.npz
#   inflating: test_data/40.npz
#   inflating: test_data/400.npz
#   inflating: test_data/401.npz
#   inflating: test_data/402.npz
#   inflating: test_data/403.npz
#   inflating: test_data/404.npz
#   inflating: test_data/405.npz
#   inflating: test_data/406.npz
#   inflating: test_data/407.npz
#   inflating: test_data/408.npz
#   inflating: test_data/409.npz
#   inflating: test_data/41.npz
#   inflating: test_data/410.npz
#   inflating: test_data/411.npz
#   inflating: test_data/412.npz
#   inflating: test_data/413.npz
#   inflating: test_data/414.npz
#   inflating: test_data/415.npz
#   inflating: test_data/416.npz
#   inflating: test_data/417.npz
#   inflating: test_data/418.npz
#   inflating: test_data/419.npz
#   inflating: test_data/42.npz
#   inflating: test_data/420.npz
#   inflating: test_data/421.npz
#   inflating: test_data/422.npz
#   inflating: test_data/423.npz
#   inflating: test_data/424.npz
#   inflating: test_data/425.npz
#   inflating: test_data/426.npz
#   inflating: test_data/427.npz
#   inflating: test_data/428.npz
#   inflating: test_data/429.npz
#   inflating: test_data/43.npz
#   inflating: test_data/430.npz
#   inflating: test_data/431.npz
#   inflating: test_data/432.npz
#   inflating: test_data/433.npz
#   inflating: test_data/434.npz
#   inflating: test_data/435.npz
#   inflating: test_data/436.npz
#   inflating: test_data/437.npz
#   inflating: test_data/438.npz
#   inflating: test_data/439.npz
#   inflating: test_data/44.npz
#   inflating: test_data/440.npz
#   inflating: test_data/441.npz
#   inflating: test_data/442.npz
#   inflating: test_data/443.npz
#   inflating: test_data/444.npz
#   inflating: test_data/445.npz
#   inflating: test_data/446.npz
#   inflating: test_data/447.npz
#   inflating: test_data/448.npz
#   inflating: test_data/449.npz
#   inflating: test_data/45.npz
#   inflating: test_data/450.npz
#   inflating: test_data/451.npz
#   inflating: test_data/452.npz
#   inflating: test_data/453.npz
#   inflating: test_data/454.npz
#   inflating: test_data/455.npz
#   inflating: test_data/456.npz
#   inflating: test_data/457.npz
#   inflating: test_data/458.npz
#   inflating: test_data/459.npz
#   inflating: test_data/46.npz
#   inflating: test_data/460.npz
#   inflating: test_data/461.npz
#   inflating: test_data/462.npz
#   inflating: test_data/463.npz
#   inflating: test_data/464.npz
#   inflating: test_data/465.npz
#   inflating: test_data/466.npz
#   inflating: test_data/467.npz
#   inflating: test_data/468.npz
#   inflating: test_data/469.npz
#   inflating: test_data/47.npz
#   inflating: test_data/470.npz
#   inflating: test_data/471.npz
#   inflating: test_data/472.npz
#   inflating: test_data/473.npz
#   inflating: test_data/474.npz
#   inflating: test_data/475.npz
#   inflating: test_data/476.npz
#   inflating: test_data/477.npz
#   inflating: test_data/478.npz
#   inflating: test_data/479.npz
#   inflating: test_data/48.npz
#   inflating: test_data/480.npz
#   inflating: test_data/481.npz
#   inflating: test_data/482.npz
#   inflating: test_data/483.npz
#   inflating: test_data/484.npz
#   inflating: test_data/485.npz
#   inflating: test_data/486.npz
#   inflating: test_data/487.npz
#   inflating: test_data/488.npz
#   inflating: test_data/489.npz
#   inflating: test_data/49.npz
#   inflating: test_data/490.npz
#   inflating: test_data/491.npz
#   inflating: test_data/492.npz
#   inflating: test_data/493.npz
#   inflating: test_data/494.npz
#   inflating: test_data/495.npz
#   inflating: test_data/496.npz
#   inflating: test_data/497.npz
#   inflating: test_data/498.npz
#   inflating: test_data/499.npz
#   inflating: test_data/5.npz
#   inflating: test_data/50.npz
#   inflating: test_data/500.npz
#   inflating: test_data/501.npz
#   inflating: test_data/502.npz
#   inflating: test_data/503.npz
#   inflating: test_data/504.npz
#   inflating: test_data/505.npz
#   inflating: test_data/506.npz
#   inflating: test_data/507.npz
#   inflating: test_data/508.npz
#   inflating: test_data/509.npz
#   inflating: test_data/51.npz
#   inflating: test_data/510.npz
#   inflating: test_data/511.npz
#   inflating: test_data/512.npz
#   inflating: test_data/513.npz
#   inflating: test_data/514.npz
#   inflating: test_data/515.npz
#   inflating: test_data/516.npz
#   inflating: test_data/517.npz
#   inflating: test_data/518.npz
#   inflating: test_data/519.npz
#   inflating: test_data/52.npz
#   inflating: test_data/520.npz
#   inflating: test_data/521.npz
#   inflating: test_data/522.npz
#   inflating: test_data/523.npz
#   inflating: test_data/524.npz
#   inflating: test_data/525.npz
#   inflating: test_data/526.npz
#   inflating: test_data/527.npz
#   inflating: test_data/528.npz
#   inflating: test_data/529.npz
#   inflating: test_data/53.npz
#   inflating: test_data/530.npz
#   inflating: test_data/531.npz
#   inflating: test_data/532.npz
#   inflating: test_data/533.npz
#   inflating: test_data/534.npz
#   inflating: test_data/535.npz
#   inflating: test_data/536.npz
#   inflating: test_data/537.npz
#   inflating: test_data/538.npz
#   inflating: test_data/539.npz
#   inflating: test_data/54.npz
#   inflating: test_data/540.npz
#   inflating: test_data/541.npz
#   inflating: test_data/542.npz
#   inflating: test_data/543.npz
#   inflating: test_data/544.npz
#   inflating: test_data/545.npz
#   inflating: test_data/546.npz
#   inflating: test_data/547.npz
#   inflating: test_data/548.npz
#   inflating: test_data/549.npz
#   inflating: test_data/55.npz
#   inflating: test_data/550.npz
#   inflating: test_data/551.npz
#   inflating: test_data/552.npz
#   inflating: test_data/553.npz
#   inflating: test_data/554.npz
#   inflating: test_data/555.npz
#   inflating: test_data/556.npz
#   inflating: test_data/557.npz
#   inflating: test_data/558.npz
#   inflating: test_data/559.npz
#   inflating: test_data/56.npz
#   inflating: test_data/560.npz
#   inflating: test_data/561.npz
#   inflating: test_data/562.npz
#   inflating: test_data/563.npz
#   inflating: test_data/564.npz
#   inflating: test_data/565.npz
#   inflating: test_data/566.npz
#   inflating: test_data/567.npz
#   inflating: test_data/568.npz
#   inflating: test_data/569.npz
#   inflating: test_data/57.npz
#   inflating: test_data/570.npz
#   inflating: test_data/571.npz
#   inflating: test_data/572.npz
#   inflating: test_data/573.npz
#   inflating: test_data/574.npz
#   inflating: test_data/575.npz
#   inflating: test_data/576.npz
#   inflating: test_data/577.npz
#   inflating: test_data/578.npz
#   inflating: test_data/579.npz
#   inflating: test_data/58.npz
#   inflating: test_data/580.npz
#   inflating: test_data/581.npz
#   inflating: test_data/582.npz
#   inflating: test_data/583.npz
#   inflating: test_data/584.npz
#   inflating: test_data/585.npz
#   inflating: test_data/586.npz
#   inflating: test_data/587.npz
#   inflating: test_data/588.npz
#   inflating: test_data/589.npz
#   inflating: test_data/59.npz
#   inflating: test_data/590.npz
#   inflating: test_data/591.npz
#   inflating: test_data/592.npz
#   inflating: test_data/593.npz
#   inflating: test_data/594.npz
#   inflating: test_data/595.npz
#   inflating: test_data/596.npz
#   inflating: test_data/597.npz
#   inflating: test_data/598.npz
#   inflating: test_data/599.npz
#   inflating: test_data/6.npz
#   inflating: test_data/60.npz
#   inflating: test_data/600.npz
#   inflating: test_data/601.npz
#   inflating: test_data/602.npz
#   inflating: test_data/603.npz
#   inflating: test_data/604.npz
#   inflating: test_data/605.npz
#   inflating: test_data/606.npz
#   inflating: test_data/607.npz
#   inflating: test_data/608.npz
#   inflating: test_data/609.npz
#   inflating: test_data/61.npz
#   inflating: test_data/610.npz
#   inflating: test_data/611.npz
#   inflating: test_data/612.npz
#   inflating: test_data/613.npz
#   inflating: test_data/614.npz
#   inflating: test_data/615.npz
#   inflating: test_data/616.npz
#   inflating: test_data/617.npz
#   inflating: test_data/618.npz
#   inflating: test_data/619.npz
#   inflating: test_data/62.npz
#   inflating: test_data/620.npz
#   inflating: test_data/621.npz
#   inflating: test_data/622.npz
#   inflating: test_data/623.npz
#   inflating: test_data/624.npz
#   inflating: test_data/625.npz
#   inflating: test_data/626.npz
#   inflating: test_data/627.npz
#   inflating: test_data/628.npz
#   inflating: test_data/629.npz
#   inflating: test_data/63.npz
#   inflating: test_data/630.npz
#   inflating: test_data/631.npz
#   inflating: test_data/632.npz
#   inflating: test_data/633.npz
#   inflating: test_data/634.npz
#   inflating: test_data/635.npz
#   inflating: test_data/636.npz
#   inflating: test_data/637.npz
#   inflating: test_data/638.npz
#   inflating: test_data/639.npz
#   inflating: test_data/64.npz
#   inflating: test_data/640.npz
#   inflating: test_data/641.npz
#   inflating: test_data/642.npz
#   inflating: test_data/643.npz
#   inflating: test_data/644.npz
#   inflating: test_data/645.npz
#   inflating: test_data/646.npz
#   inflating: test_data/647.npz
#   inflating: test_data/648.npz
#   inflating: test_data/649.npz
#   inflating: test_data/65.npz
#   inflating: test_data/650.npz
#   inflating: test_data/651.npz
#   inflating: test_data/652.npz
#   inflating: test_data/653.npz
#   inflating: test_data/654.npz
#   inflating: test_data/655.npz
#   inflating: test_data/656.npz
#   inflating: test_data/657.npz
#   inflating: test_data/658.npz
#   inflating: test_data/659.npz
#   inflating: test_data/66.npz
#   inflating: test_data/660.npz
#   inflating: test_data/661.npz
#   inflating: test_data/662.npz
#   inflating: test_data/663.npz
#   inflating: test_data/664.npz
#   inflating: test_data/665.npz
#   inflating: test_data/666.npz
#   inflating: test_data/667.npz
#   inflating: test_data/668.npz
#   inflating: test_data/669.npz
#   inflating: test_data/67.npz
#   inflating: test_data/670.npz
#   inflating: test_data/671.npz
#   inflating: test_data/672.npz
#   inflating: test_data/673.npz
#   inflating: test_data/674.npz
#   inflating: test_data/675.npz
#   inflating: test_data/676.npz
#   inflating: test_data/677.npz
#   inflating: test_data/678.npz
#   inflating: test_data/679.npz
#   inflating: test_data/68.npz
#   inflating: test_data/680.npz
#   inflating: test_data/681.npz
#   inflating: test_data/682.npz
#   inflating: test_data/683.npz
#   inflating: test_data/684.npz
#   inflating: test_data/685.npz
#   inflating: test_data/686.npz
#   inflating: test_data/687.npz
#   inflating: test_data/688.npz
#   inflating: test_data/689.npz
#   inflating: test_data/69.npz
#   inflating: test_data/690.npz
#   inflating: test_data/691.npz
#   inflating: test_data/692.npz
#   inflating: test_data/693.npz
#   inflating: test_data/694.npz
#   inflating: test_data/695.npz
#   inflating: test_data/696.npz
#   inflating: test_data/697.npz
#   inflating: test_data/698.npz
#   inflating: test_data/699.npz
#   inflating: test_data/7.npz
#   inflating: test_data/70.npz
#   inflating: test_data/700.npz
#   inflating: test_data/701.npz
#   inflating: test_data/702.npz
#   inflating: test_data/703.npz
#   inflating: test_data/704.npz
#   inflating: test_data/705.npz
#   inflating: test_data/706.npz
#   inflating: test_data/707.npz
#   inflating: test_data/708.npz
#   inflating: test_data/709.npz
#   inflating: test_data/71.npz
#   inflating: test_data/710.npz
#   inflating: test_data/711.npz
#   inflating: test_data/712.npz
#   inflating: test_data/713.npz
#   inflating: test_data/714.npz
#   inflating: test_data/715.npz
#   inflating: test_data/716.npz
#   inflating: test_data/717.npz
#   inflating: test_data/718.npz
#   inflating: test_data/719.npz
#   inflating: test_data/72.npz
#   inflating: test_data/720.npz
#   inflating: test_data/721.npz
#   inflating: test_data/722.npz
#   inflating: test_data/723.npz
#   inflating: test_data/724.npz
#   inflating: test_data/725.npz
#   inflating: test_data/726.npz
#   inflating: test_data/727.npz
#   inflating: test_data/728.npz
#   inflating: test_data/729.npz
#   inflating: test_data/73.npz
#   inflating: test_data/730.npz
#   inflating: test_data/731.npz
#   inflating: test_data/732.npz
#   inflating: test_data/733.npz
#   inflating: test_data/734.npz
#   inflating: test_data/735.npz
#   inflating: test_data/736.npz
#   inflating: test_data/737.npz
#   inflating: test_data/738.npz
#   inflating: test_data/739.npz
#   inflating: test_data/74.npz
#   inflating: test_data/740.npz
#   inflating: test_data/741.npz
#   inflating: test_data/742.npz
#   inflating: test_data/743.npz
#   inflating: test_data/744.npz
#   inflating: test_data/745.npz
#   inflating: test_data/746.npz
#   inflating: test_data/747.npz
#   inflating: test_data/748.npz
#   inflating: test_data/749.npz
#   inflating: test_data/75.npz
#   inflating: test_data/750.npz
#   inflating: test_data/751.npz
#   inflating: test_data/752.npz
#   inflating: test_data/753.npz
#   inflating: test_data/754.npz
#   inflating: test_data/755.npz
#   inflating: test_data/756.npz
#   inflating: test_data/757.npz
#   inflating: test_data/758.npz
#   inflating: test_data/759.npz
#   inflating: test_data/76.npz
#   inflating: test_data/760.npz
#   inflating: test_data/761.npz
#   inflating: test_data/762.npz
#   inflating: test_data/763.npz
#   inflating: test_data/764.npz
#   inflating: test_data/765.npz
#   inflating: test_data/766.npz
#   inflating: test_data/767.npz
#   inflating: test_data/768.npz
#   inflating: test_data/769.npz
#   inflating: test_data/77.npz
#   inflating: test_data/770.npz
#   inflating: test_data/771.npz
#   inflating: test_data/772.npz
#   inflating: test_data/773.npz
#   inflating: test_data/774.npz
#   inflating: test_data/775.npz
#   inflating: test_data/776.npz
#   inflating: test_data/777.npz
#   inflating: test_data/778.npz
#   inflating: test_data/779.npz
#   inflating: test_data/78.npz
#   inflating: test_data/780.npz
#   inflating: test_data/781.npz
#   inflating: test_data/782.npz
#   inflating: test_data/783.npz
#   inflating: test_data/784.npz
#   inflating: test_data/785.npz
#   inflating: test_data/786.npz
#   inflating: test_data/787.npz
#   inflating: test_data/788.npz
#   inflating: test_data/789.npz
#   inflating: test_data/79.npz
#   inflating: test_data/790.npz
#   inflating: test_data/791.npz
#   inflating: test_data/792.npz
#   inflating: test_data/793.npz
#   inflating: test_data/794.npz
#   inflating: test_data/795.npz
#   inflating: test_data/796.npz
#   inflating: test_data/797.npz
#   inflating: test_data/798.npz
#   inflating: test_data/799.npz
#   inflating: test_data/8.npz
#   inflating: test_data/80.npz
#   inflating: test_data/800.npz
#   inflating: test_data/801.npz
#   inflating: test_data/802.npz
#   inflating: test_data/803.npz
#   inflating: test_data/804.npz
#   inflating: test_data/805.npz
#   inflating: test_data/806.npz
#   inflating: test_data/807.npz
#   inflating: test_data/808.npz
#   inflating: test_data/809.npz
#   inflating: test_data/81.npz
#   inflating: test_data/810.npz
#   inflating: test_data/811.npz
#   inflating: test_data/812.npz
#   inflating: test_data/813.npz
#   inflating: test_data/814.npz
#   inflating: test_data/815.npz
#   inflating: test_data/816.npz
#   inflating: test_data/817.npz
#   inflating: test_data/818.npz
#   inflating: test_data/819.npz
#   inflating: test_data/82.npz
#   inflating: test_data/820.npz
#   inflating: test_data/821.npz
#   inflating: test_data/822.npz
#   inflating: test_data/823.npz
#   inflating: test_data/824.npz
#   inflating: test_data/825.npz
#   inflating: test_data/826.npz
#   inflating: test_data/827.npz
#   inflating: test_data/828.npz
#   inflating: test_data/829.npz
#   inflating: test_data/83.npz
#   inflating: test_data/830.npz
#   inflating: test_data/831.npz
#   inflating: test_data/832.npz
#   inflating: test_data/833.npz
#   inflating: test_data/834.npz
#   inflating: test_data/835.npz
#   inflating: test_data/836.npz
#   inflating: test_data/837.npz
#   inflating: test_data/838.npz
#   inflating: test_data/839.npz
#   inflating: test_data/84.npz
#   inflating: test_data/840.npz
#   inflating: test_data/841.npz
#   inflating: test_data/842.npz
#   inflating: test_data/843.npz
#   inflating: test_data/844.npz
#   inflating: test_data/845.npz
#   inflating: test_data/846.npz
#   inflating: test_data/847.npz
#   inflating: test_data/848.npz
#   inflating: test_data/849.npz
#   inflating: test_data/85.npz
#   inflating: test_data/850.npz
#   inflating: test_data/851.npz
#   inflating: test_data/852.npz
#   inflating: test_data/853.npz
#   inflating: test_data/854.npz
#   inflating: test_data/855.npz
#   inflating: test_data/856.npz
#   inflating: test_data/857.npz
#   inflating: test_data/858.npz
#   inflating: test_data/859.npz
#   inflating: test_data/86.npz
#   inflating: test_data/860.npz
#   inflating: test_data/861.npz
#   inflating: test_data/862.npz
#   inflating: test_data/863.npz
#   inflating: test_data/864.npz
#   inflating: test_data/865.npz
#   inflating: test_data/866.npz
#   inflating: test_data/867.npz
#   inflating: test_data/868.npz
#   inflating: test_data/869.npz
#   inflating: test_data/87.npz
#   inflating: test_data/870.npz
#   inflating: test_data/871.npz
#   inflating: test_data/872.npz
#   inflating: test_data/873.npz
#   inflating: test_data/874.npz
#   inflating: test_data/875.npz
#   inflating: test_data/876.npz
#   inflating: test_data/877.npz
#   inflating: test_data/878.npz
#   inflating: test_data/879.npz
#   inflating: test_data/88.npz
#   inflating: test_data/880.npz
#   inflating: test_data/881.npz
#   inflating: test_data/882.npz
#   inflating: test_data/883.npz
#   inflating: test_data/884.npz
#   inflating: test_data/885.npz
#   inflating: test_data/886.npz
#   inflating: test_data/887.npz
#   inflating: test_data/888.npz
#   inflating: test_data/889.npz
#   inflating: test_data/89.npz
#   inflating: test_data/890.npz
#   inflating: test_data/891.npz
#   inflating: test_data/892.npz
#   inflating: test_data/893.npz
#   inflating: test_data/894.npz
#   inflating: test_data/895.npz
#   inflating: test_data/896.npz
#   inflating: test_data/897.npz
#   inflating: test_data/898.npz
#   inflating: test_data/899.npz
#   inflating: test_data/9.npz
#   inflating: test_data/90.npz
#   inflating: test_data/900.npz
#   inflating: test_data/901.npz
#   inflating: test_data/902.npz
#   inflating: test_data/903.npz
#   inflating: test_data/904.npz
#   inflating: test_data/905.npz
#   inflating: test_data/906.npz
#   inflating: test_data/907.npz
#   inflating: test_data/908.npz
#   inflating: test_data/909.npz
#   inflating: test_data/91.npz
#   inflating: test_data/910.npz
#   inflating: test_data/911.npz
#   inflating: test_data/912.npz
#   inflating: test_data/913.npz
#   inflating: test_data/914.npz
#   inflating: test_data/915.npz
#   inflating: test_data/916.npz
#   inflating: test_data/917.npz
#   inflating: test_data/918.npz
#   inflating: test_data/919.npz
#   inflating: test_data/92.npz
#   inflating: test_data/920.npz
#   inflating: test_data/921.npz
#   inflating: test_data/922.npz
#   inflating: test_data/923.npz
#   inflating: test_data/924.npz
#   inflating: test_data/925.npz
#   inflating: test_data/926.npz
#   inflating: test_data/927.npz
#   inflating: test_data/928.npz
#   inflating: test_data/929.npz
#   inflating: test_data/93.npz
#   inflating: test_data/930.npz
#   inflating: test_data/931.npz
#   inflating: test_data/932.npz
#   inflating: test_data/933.npz
#   inflating: test_data/934.npz
#   inflating: test_data/935.npz
#   inflating: test_data/936.npz
#   inflating: test_data/937.npz
#   inflating: test_data/938.npz
#   inflating: test_data/939.npz
#   inflating: test_data/94.npz
#   inflating: test_data/940.npz
#   inflating: test_data/941.npz
#   inflating: test_data/942.npz
#   inflating: test_data/943.npz
#   inflating: test_data/944.npz
#   inflating: test_data/945.npz
#   inflating: test_data/946.npz
#   inflating: test_data/947.npz
#   inflating: test_data/948.npz
#   inflating: test_data/949.npz
#   inflating: test_data/95.npz
#   inflating: test_data/950.npz
#   inflating: test_data/951.npz
#   inflating: test_data/952.npz
#   inflating: test_data/953.npz
#   inflating: test_data/954.npz
#   inflating: test_data/955.npz
#   inflating: test_data/956.npz
#   inflating: test_data/957.npz
#   inflating: test_data/958.npz
#   inflating: test_data/959.npz
#   inflating: test_data/96.npz
#   inflating: test_data/960.npz
#   inflating: test_data/961.npz
#   inflating: test_data/962.npz
#   inflating: test_data/963.npz
#   inflating: test_data/964.npz
#   inflating: test_data/965.npz
#   inflating: test_data/966.npz
#   inflating: test_data/967.npz
#   inflating: test_data/968.npz
#   inflating: test_data/969.npz
#   inflating: test_data/97.npz
#   inflating: test_data/970.npz
#   inflating: test_data/971.npz
#   inflating: test_data/972.npz
#   inflating: test_data/973.npz
#   inflating: test_data/974.npz
#   inflating: test_data/975.npz
#   inflating: test_data/976.npz
#   inflating: test_data/977.npz
#   inflating: test_data/978.npz
#   inflating: test_data/979.npz
#   inflating: test_data/98.npz
#   inflating: test_data/980.npz
#   inflating: test_data/981.npz
#   inflating: test_data/982.npz
#   inflating: test_data/983.npz
#   inflating: test_data/984.npz
#   inflating: test_data/985.npz
#   inflating: test_data/986.npz
#   inflating: test_data/987.npz
#   inflating: test_data/988.npz
#   inflating: test_data/989.npz
#   inflating: test_data/99.npz
#   inflating: test_data/990.npz
#   inflating: test_data/991.npz
#   inflating: test_data/992.npz
#   inflating: test_data/993.npz
#   inflating: test_data/994.npz
#   inflating: test_data/995.npz
#   inflating: test_data/996.npz
#   inflating: test_data/997.npz
#   inflating: test_data/998.npz
#   inflating: test_data/999.npz
# Archive:  train_data.zip
#    creating: train_data/
#   inflating: __MACOSX/._train_data
#   inflating: train_data/train_gt.csv
#   inflating: __MACOSX/train_data/._train_gt.csv
#    creating: train_data/train_data/
#   inflating: __MACOSX/train_data/._train_data
#   inflating: train_data/wavelengths.csv
#   inflating: __MACOSX/train_data/._wavelengths.csv
#   inflating: train_data/train_data/77.npz
#   inflating: __MACOSX/train_data/train_data/._77.npz
#   inflating: train_data/train_data/837.npz
#   inflating: __MACOSX/train_data/train_data/._837.npz
#   inflating: train_data/train_data/189.npz
#   inflating: __MACOSX/train_data/train_data/._189.npz
#   inflating: train_data/train_data/1409.npz
#   inflating: __MACOSX/train_data/train_data/._1409.npz
#   inflating: train_data/train_data/63.npz
#   inflating: __MACOSX/train_data/train_data/._63.npz
#   inflating: train_data/train_data/823.npz
#   inflating: __MACOSX/train_data/train_data/._823.npz
#   inflating: train_data/train_data/1347.npz
#   inflating: __MACOSX/train_data/train_data/._1347.npz
#   inflating: train_data/train_data/1421.npz
#   inflating: __MACOSX/train_data/train_data/._1421.npz
#   inflating: train_data/train_data/1435.npz
#   inflating: __MACOSX/train_data/train_data/._1435.npz
#   inflating: train_data/train_data/1353.npz
#   inflating: __MACOSX/train_data/train_data/._1353.npz
#   inflating: train_data/train_data/638.npz
#   inflating: __MACOSX/train_data/train_data/._638.npz
#   inflating: train_data/train_data/610.npz
#   inflating: __MACOSX/train_data/train_data/._610.npz
#   inflating: train_data/train_data/1384.npz
#   inflating: __MACOSX/train_data/train_data/._1384.npz
#   inflating: train_data/train_data/88.npz
#   inflating: __MACOSX/train_data/train_data/._88.npz
#   inflating: train_data/train_data/176.npz
#   inflating: __MACOSX/train_data/train_data/._176.npz
#   inflating: train_data/train_data/162.npz
#   inflating: __MACOSX/train_data/train_data/._162.npz
#   inflating: train_data/train_data/1390.npz
#   inflating: __MACOSX/train_data/train_data/._1390.npz
#   inflating: train_data/train_data/604.npz
#   inflating: __MACOSX/train_data/train_data/._604.npz
#   inflating: train_data/train_data/1179.npz
#   inflating: __MACOSX/train_data/train_data/._1179.npz
#   inflating: train_data/train_data/1623.npz
#   inflating: __MACOSX/train_data/train_data/._1623.npz
#   inflating: train_data/train_data/1145.npz
#   inflating: __MACOSX/train_data/train_data/._1145.npz
#   inflating: train_data/train_data/1151.npz
#   inflating: __MACOSX/train_data/train_data/._1151.npz
#   inflating: train_data/train_data/1637.npz
#   inflating: __MACOSX/train_data/train_data/._1637.npz
#   inflating: train_data/train_data/348.npz
#   inflating: __MACOSX/train_data/train_data/._348.npz
#   inflating: train_data/train_data/374.npz
# ...
#   inflating: __MACOSX/train_data/train_data/._959.npz
#   inflating: train_data/train_data/1573.npz
#   inflating: __MACOSX/train_data/train_data/._1573.npz
#   inflating: train_data/train_data/1567.npz
#   inflating: __MACOSX/train_data/train_data/._1567.npz
#   inflating: train_data/train_data/1201.npz
#   inflating: __MACOSX/train_data/train_data/._1201.npz
#   inflating: train_data/train_data/795.npz
#   inflating: __MACOSX/train_data/train_data/._795.npz
#   inflating: train_data/train_data/568.npz
#   inflating: __MACOSX/train_data/train_data/._568.npz
#   inflating: train_data/train_data/226.npz
#   inflating: __MACOSX/train_data/train_data/._226.npz
#   inflating: train_data/train_data/540.npz
#   inflating: __MACOSX/train_data/train_data/._540.npz
#   inflating: train_data/train_data/554.npz
#   inflating: __MACOSX/train_data/train_data/._554.npz
#   inflating: train_data/train_data/232.npz
#   inflating: __MACOSX/train_data/train_data/._232.npz
#   inflating: train_data/train_data/1017.npz
#   inflating: __MACOSX/train_data/train_data/._1017.npz
#   inflating: train_data/train_data/583.npz
#   inflating: __MACOSX/train_data/train_data/._583.npz
#   inflating: train_data/train_data/597.npz
#   inflating: __MACOSX/train_data/train_data/._597.npz
#   inflating: train_data/train_data/1003.npz
#   inflating: __MACOSX/train_data/train_data/._1003.npz
#   inflating: train_data/train_data/408.npz
#   inflating: __MACOSX/train_data/train_data/._408.npz
#   inflating: train_data/train_data/1188.npz
#   inflating: __MACOSX/train_data/train_data/._1188.npz
#   inflating: train_data/train_data/352.npz
#   inflating: __MACOSX/train_data/train_data/._352.npz
#   inflating: train_data/train_data/434.npz
#   inflating: __MACOSX/train_data/train_data/._434.npz
#   inflating: train_data/train_data/420.npz
#   inflating: __MACOSX/train_data/train_data/._420.npz
#   inflating: train_data/train_data/346.npz
#   inflating: __MACOSX/train_data/train_data/._346.npz
#   inflating: train_data/train_data/1639.npz
#   inflating: __MACOSX/train_data/train_data/._1639.npz
#   inflating: train_data/train_data/1605.npz
#   inflating: __MACOSX/train_data/train_data/._1605.npz
#   inflating: train_data/train_data/391.npz
#   inflating: __MACOSX/train_data/train_data/._391.npz
#   inflating: train_data/train_data/1163.npz
#   inflating: __MACOSX/train_data/train_data/._1163.npz
#   inflating: train_data/train_data/1177.npz
#   inflating: __MACOSX/train_data/train_data/._1177.npz
#   inflating: train_data/train_data/385.npz
#   inflating: __MACOSX/train_data/train_data/._385.npz
#   inflating: train_data/train_data/1611.npz
#   inflating: __MACOSX/train_data/train_data/._1611.npz
#   inflating: train_data/train_data/92.npz
#   inflating: __MACOSX/train_data/train_data/._92.npz
#   inflating: train_data/train_data/178.npz
#   inflating: __MACOSX/train_data/train_data/._178.npz
#   inflating: train_data/train_data/86.npz
#   inflating: __MACOSX/train_data/train_data/._86.npz
#   inflating: train_data/train_data/636.npz
#   inflating: __MACOSX/train_data/train_data/._636.npz
#   inflating: train_data/train_data/150.npz
#   inflating: __MACOSX/train_data/train_data/._150.npz
#   inflating: train_data/train_data/144.npz
#   inflating: __MACOSX/train_data/train_data/._144.npz
#   inflating: train_data/train_data/622.npz
#   inflating: __MACOSX/train_data/train_data/._622.npz
#   inflating: train_data/train_data/811.npz
#   inflating: __MACOSX/train_data/train_data/._811.npz
#   inflating: train_data/train_data/51.npz
#   inflating: __MACOSX/train_data/train_data/._51.npz
#   inflating: train_data/train_data/3.npz
#   inflating: __MACOSX/train_data/train_data/._3.npz
#   inflating: train_data/train_data/805.npz
#   inflating: __MACOSX/train_data/train_data/._805.npz
#   inflating: train_data/train_data/1349.npz
#   inflating: __MACOSX/train_data/train_data/._1349.npz
#   inflating: train_data/train_data/45.npz
#   inflating: __MACOSX/train_data/train_data/._45.npz
#   inflating: train_data/train_data/1361.npz
#   inflating: __MACOSX/train_data/train_data/._1361.npz
#   inflating: train_data/train_data/193.npz
#   inflating: __MACOSX/train_data/train_data/._193.npz
#   inflating: train_data/train_data/1407.npz
#   inflating: __MACOSX/train_data/train_data/._1407.npz
#   inflating: train_data/train_data/1413.npz
#   inflating: __MACOSX/train_data/train_data/._1413.npz
#   inflating: train_data/train_data/187.npz
#   inflating: __MACOSX/train_data/train_data/._187.npz
#   inflating: train_data/train_data/839.npz
#   inflating: __MACOSX/train_data/train_data/._839.npz
#   inflating: train_data/train_data/1375.npz
#   inflating: __MACOSX/train_data/train_data/._1375.npz
#   inflating: train_data/train_data/79.npz
#   inflating: __MACOSX/train_data/train_data/._79.npz
#   inflating: train_data/train_data/1405.npz
#   inflating: __MACOSX/train_data/train_data/._1405.npz
#   inflating: train_data/train_data/191.npz
#   inflating: __MACOSX/train_data/train_data/._191.npz
#   inflating: train_data/train_data/1363.npz
#   inflating: __MACOSX/train_data/train_data/._1363.npz
#   inflating: train_data/train_data/1377.npz
#   inflating: __MACOSX/train_data/train_data/._1377.npz
#   inflating: train_data/train_data/185.npz
#   inflating: __MACOSX/train_data/train_data/._185.npz
#   inflating: train_data/train_data/1411.npz
#   inflating: __MACOSX/train_data/train_data/._1411.npz
#   inflating: train_data/train_data/1.npz
#   inflating: __MACOSX/train_data/train_data/._1.npz
#   inflating: train_data/train_data/1439.npz
#   inflating: __MACOSX/train_data/train_data/._1439.npz
#   inflating: train_data/train_data/53.npz
#   inflating: __MACOSX/train_data/train_data/._53.npz
#   inflating: train_data/train_data/813.npz
#   inflating: __MACOSX/train_data/train_data/._813.npz
#   inflating: train_data/train_data/47.npz
#   inflating: __MACOSX/train_data/train_data/._47.npz
#   inflating: train_data/train_data/807.npz
#   inflating: __MACOSX/train_data/train_data/._807.npz
#   inflating: train_data/train_data/152.npz
#   inflating: __MACOSX/train_data/train_data/._152.npz
#   inflating: train_data/train_data/634.npz
#   inflating: __MACOSX/train_data/train_data/._634.npz
#   inflating: train_data/train_data/620.npz
#   inflating: __MACOSX/train_data/train_data/._620.npz
#   inflating: train_data/train_data/146.npz
#   inflating: __MACOSX/train_data/train_data/._146.npz
#   inflating: train_data/train_data/90.npz
#   inflating: __MACOSX/train_data/train_data/._90.npz
#   inflating: train_data/train_data/608.npz
#   inflating: __MACOSX/train_data/train_data/._608.npz
#   inflating: train_data/train_data/84.npz
#   inflating: __MACOSX/train_data/train_data/._84.npz
#   inflating: train_data/train_data/1388.npz
#   inflating: __MACOSX/train_data/train_data/._1388.npz
#   inflating: train_data/train_data/1161.npz
#   inflating: __MACOSX/train_data/train_data/._1161.npz
#   inflating: train_data/train_data/393.npz
#   inflating: __MACOSX/train_data/train_data/._393.npz
#   inflating: train_data/train_data/1607.npz
#   inflating: __MACOSX/train_data/train_data/._1607.npz
#   inflating: train_data/train_data/1613.npz
#   inflating: __MACOSX/train_data/train_data/._1613.npz
#   inflating: train_data/train_data/387.npz
#   inflating: __MACOSX/train_data/train_data/._387.npz
#   inflating: train_data/train_data/1175.npz
#   inflating: __MACOSX/train_data/train_data/._1175.npz
#   inflating: train_data/train_data/1149.npz
#   inflating: __MACOSX/train_data/train_data/._1149.npz
#   inflating: train_data/train_data/436.npz
#   inflating: __MACOSX/train_data/train_data/._436.npz
#   inflating: train_data/train_data/350.npz
#   inflating: __MACOSX/train_data/train_data/._350.npz
#   inflating: train_data/train_data/344.npz
#   inflating: __MACOSX/train_data/train_data/._344.npz
#   inflating: train_data/train_data/422.npz
#   inflating: __MACOSX/train_data/train_data/._422.npz
#   inflating: train_data/train_data/378.npz
#   inflating: __MACOSX/train_data/train_data/._378.npz
#   inflating: train_data/train_data/581.npz
#   inflating: __MACOSX/train_data/train_data/._581.npz
#   inflating: train_data/train_data/1015.npz
#   inflating: __MACOSX/train_data/train_data/._1015.npz
#   inflating: train_data/train_data/1001.npz
#   inflating: __MACOSX/train_data/train_data/._1001.npz
#   inflating: train_data/train_data/595.npz
#   inflating: __MACOSX/train_data/train_data/._595.npz
#   inflating: train_data/train_data/1029.npz
#   inflating: __MACOSX/train_data/train_data/._1029.npz
#   inflating: train_data/train_data/542.npz
#   inflating: __MACOSX/train_data/train_data/._542.npz
#   inflating: train_data/train_data/224.npz
#   inflating: __MACOSX/train_data/train_data/._224.npz
#   inflating: train_data/train_data/230.npz
#   inflating: __MACOSX/train_data/train_data/._230.npz
#   inflating: train_data/train_data/556.npz
#   inflating: __MACOSX/train_data/train_data/._556.npz
#   inflating: train_data/train_data/218.npz
#   inflating: __MACOSX/train_data/train_data/._218.npz
#   inflating: train_data/train_data/1571.npz
#   inflating: __MACOSX/train_data/train_data/._1571.npz
#   inflating: train_data/train_data/1217.npz
#   inflating: __MACOSX/train_data/train_data/._1217.npz
#   inflating: train_data/train_data/783.npz
#   inflating: __MACOSX/train_data/train_data/._783.npz
#   inflating: train_data/train_data/797.npz
#   inflating: __MACOSX/train_data/train_data/._797.npz
#   inflating: train_data/train_data/1203.npz
#   inflating: __MACOSX/train_data/train_data/._1203.npz
#   inflating: train_data/train_data/1565.npz
#   inflating: __MACOSX/train_data/train_data/._1565.npz
#   inflating: train_data/train_data/967.npz
#   inflating: __MACOSX/train_data/train_data/._967.npz
#   inflating: train_data/train_data/973.npz
#   inflating: __MACOSX/train_data/train_data/._973.npz
#   inflating: train_data/train_data/1559.npz
#   inflating: __MACOSX/train_data/train_data/._1559.npz
#   inflating: train_data/train_data/740.npz
#   inflating: __MACOSX/train_data/train_data/._740.npz
#   inflating: train_data/train_data/998.npz
#   inflating: __MACOSX/train_data/train_data/._998.npz
#   inflating: train_data/train_data/754.npz
#   inflating: __MACOSX/train_data/train_data/._754.npz
#   inflating: train_data/train_data/768.npz
#   inflating: __MACOSX/train_data/train_data/._768.npz
#   inflating: train_data/train_data/769.npz
#   inflating: __MACOSX/train_data/train_data/._769.npz
#   inflating: train_data/train_data/755.npz
#   inflating: __MACOSX/train_data/train_data/._755.npz
#   inflating: train_data/train_data/999.npz
#   inflating: __MACOSX/train_data/train_data/._999.npz
#   inflating: train_data/train_data/741.npz
#   inflating: __MACOSX/train_data/train_data/._741.npz
#   inflating: train_data/train_data/972.npz
#   inflating: __MACOSX/train_data/train_data/._972.npz
#   inflating: train_data/train_data/1558.npz
#   inflating: __MACOSX/train_data/train_data/._1558.npz
#   inflating: train_data/train_data/966.npz
#   inflating: __MACOSX/train_data/train_data/._966.npz
#   inflating: train_data/train_data/1202.npz
#   inflating: __MACOSX/train_data/train_data/._1202.npz
#   inflating: train_data/train_data/796.npz
#   inflating: __MACOSX/train_data/train_data/._796.npz
#   inflating: train_data/train_data/1564.npz
#   inflating: __MACOSX/train_data/train_data/._1564.npz
#   inflating: train_data/train_data/1570.npz
#   inflating: __MACOSX/train_data/train_data/._1570.npz
#   inflating: train_data/train_data/782.npz
#   inflating: __MACOSX/train_data/train_data/._782.npz
#   inflating: train_data/train_data/1216.npz
#   inflating: __MACOSX/train_data/train_data/._1216.npz
#   inflating: train_data/train_data/219.npz
#   inflating: __MACOSX/train_data/train_data/._219.npz
#   inflating: train_data/train_data/231.npz
#   inflating: __MACOSX/train_data/train_data/._231.npz
#   inflating: train_data/train_data/557.npz
#   inflating: __MACOSX/train_data/train_data/._557.npz
#   inflating: train_data/train_data/543.npz
#   inflating: __MACOSX/train_data/train_data/._543.npz
#   inflating: train_data/train_data/225.npz
#   inflating: __MACOSX/train_data/train_data/._225.npz
#   inflating: train_data/train_data/1028.npz
#   inflating: __MACOSX/train_data/train_data/._1028.npz
#   inflating: train_data/train_data/594.npz
#   inflating: __MACOSX/train_data/train_data/._594.npz
#   inflating: train_data/train_data/1000.npz
#   inflating: __MACOSX/train_data/train_data/._1000.npz
#   inflating: train_data/train_data/1014.npz
#   inflating: __MACOSX/train_data/train_data/._1014.npz
#   inflating: train_data/train_data/580.npz
#   inflating: __MACOSX/train_data/train_data/._580.npz
#   inflating: train_data/train_data/379.npz
#   inflating: __MACOSX/train_data/train_data/._379.npz
#   inflating: train_data/train_data/345.npz
#   inflating: __MACOSX/train_data/train_data/._345.npz
#   inflating: train_data/train_data/423.npz
#   inflating: __MACOSX/train_data/train_data/._423.npz
#   inflating: train_data/train_data/437.npz
#   inflating: __MACOSX/train_data/train_data/._437.npz
#   inflating: train_data/train_data/351.npz
#   inflating: __MACOSX/train_data/train_data/._351.npz
#   inflating: train_data/train_data/1148.npz
#   inflating: __MACOSX/train_data/train_data/._1148.npz
#   inflating: train_data/train_data/386.npz
#   inflating: __MACOSX/train_data/train_data/._386.npz
#   inflating: train_data/train_data/1612.npz
#   inflating: __MACOSX/train_data/train_data/._1612.npz
#   inflating: train_data/train_data/1174.npz
#   inflating: __MACOSX/train_data/train_data/._1174.npz
#   inflating: train_data/train_data/1160.npz
#   inflating: __MACOSX/train_data/train_data/._1160.npz
#   inflating: train_data/train_data/1606.npz
#   inflating: __MACOSX/train_data/train_data/._1606.npz
#   inflating: train_data/train_data/392.npz
#   inflating: __MACOSX/train_data/train_data/._392.npz
#   inflating: train_data/train_data/1389.npz
#   inflating: __MACOSX/train_data/train_data/._1389.npz
#   inflating: train_data/train_data/85.npz
#   inflating: __MACOSX/train_data/train_data/._85.npz
#   inflating: train_data/train_data/609.npz
#   inflating: __MACOSX/train_data/train_data/._609.npz
#   inflating: train_data/train_data/91.npz
#   inflating: __MACOSX/train_data/train_data/._91.npz
#   inflating: train_data/train_data/621.npz
#   inflating: __MACOSX/train_data/train_data/._621.npz
#   inflating: train_data/train_data/147.npz
#   inflating: __MACOSX/train_data/train_data/._147.npz
#   inflating: train_data/train_data/153.npz
#   inflating: __MACOSX/train_data/train_data/._153.npz
#   inflating: train_data/train_data/635.npz
#   inflating: __MACOSX/train_data/train_data/._635.npz
#   inflating: train_data/train_data/806.npz
#   inflating: __MACOSX/train_data/train_data/._806.npz
#   inflating: train_data/train_data/46.npz
#   inflating: __MACOSX/train_data/train_data/._46.npz
#   inflating: train_data/train_data/1438.npz
#   inflating: __MACOSX/train_data/train_data/._1438.npz
#   inflating: train_data/train_data/0.npz
#   inflating: __MACOSX/train_data/train_data/._0.npz
#   inflating: train_data/train_data/812.npz
#   inflating: __MACOSX/train_data/train_data/._812.npz
#   inflating: train_data/train_data/52.npz
#   inflating: __MACOSX/train_data/train_data/._52.npz
#   inflating: train_data/train_data/1376.npz
#   inflating: __MACOSX/train_data/train_data/._1376.npz
#   inflating: train_data/train_data/1410.npz
#   inflating: __MACOSX/train_data/train_data/._1410.npz
#   inflating: train_data/train_data/184.npz
#   inflating: __MACOSX/train_data/train_data/._184.npz
#   inflating: train_data/train_data/190.npz
#   inflating: __MACOSX/train_data/train_data/._190.npz
#   inflating: train_data/train_data/1404.npz
#   inflating: __MACOSX/train_data/train_data/._1404.npz
#   inflating: train_data/train_data/1362.npz
#   inflating: __MACOSX/train_data/train_data/._1362.npz

# %%
# SOME CONSTANTS UTILIZED IN THE NOTEBOOK
DEBUG = False 
AUGMENT_CONSTANT_RF=1 
AUGMENT_CONSTANT_KNN=1 
LABEL_NAMES = ["P", "K", "Mg", "pH"] 
#LABEL_MAXS = np.array([325.0, 625.0, 400.0, 7.8]) 
LABEL_MAXS = np.array([1, 1, 1, 1]) 
#Y_BASE_FACT = np.array([121764.2 / 1731.0, 394876.1 / 1731.0, 275875.1 / 1731.0, 11747.67 / 1731.0]) / LABEL_MAXS 
COL_IX = [0, 1, 2, 3]

# %%
def load_data(directory: str, gt_file_path: str, is_train=True, augment_constant: int = 0):
    """Load each cube, reduce its dimensionality and append to array.

    Args:
        directory (str): Directory to either train or test set
        gt_file_path (str): File path for the ground truth labels (expected CVS file)
        is_train (boolean): Binary flag for setting loader for Train (TRUE) or Test (FALSE)
        augment_constant (int): number of augmentation steps to randomly crop from the larger agricultural fields
    Returns:
        [type]: Tuple of lists composed of raw field (data , mask) pairs,
                and if exists: (augmented data, augmented mask) pairs, and ground truth labels
    """
    
    datalist = []
    masklist = []
    aug_datalist = []
    aug_masklist = []
    aug_labellist = []

    if is_train:
        labels = load_gt(gt_file_path)

    all_files = np.array(
        sorted(
            glob(os.path.join(directory, "*.npz")),
            key=lambda x: int(os.path.basename(x).replace(".npz", "")),
        )
    )

    if DEBUG:
        all_files = all_files[:100]
        if is_train:
            labels = labels[:100]

    for idx, file_name in tqdm(enumerate(all_files),total=len(all_files), desc="Loading {} data .."
                               .format("training" if is_train else "test")):
       # We load the data into memory as provided in the example notebook of the challenge
        with np.load(file_name) as npz:
            mask = npz["mask"]
            data = npz["data"]
            datalist.append(data)
            masklist.append(mask)
            
    # for training data we make pre-augmentation by adding some randomly cropped samples
    if is_train: 
        for i in range(augment_constant):
            for idx, file_name in tqdm(enumerate(all_files),total=len(all_files), desc="Loading augmentation {} ..".format(i+1)):
                # print(file_name)
                with np.load(file_name) as npz:
                    flag = True
                    mask = npz["mask"]
                    data = npz["data"]
                    ma = np.max(data, keepdims=True)
                    sh = data.shape[1:]
                    for i in range(0): 
                        # Repeating 11x11 cropping 10 times does not mean we use all croppings:
                        # as seen in the Flag=False below at the end of the loop, 
                        # when we reach at the good crop (not coinciding to the masked area) we stop searching 
                        
                        # Randomly cropping the fields with 11x11 size, 
                        # and adding some noise to the cropped samples 
                        edge = 11  
                        x = np.random.randint(sh[0] + 1 - edge)
                        y = np.random.randint(sh[1] + 1 - edge)
                        
                        # get crops having meaningful pixels, not zeros
                        if np.sum(mask[0, x : (x + edge), y : (y + edge)]) > 120: 
                            aug_data = (data[:, x : (x + edge), y : (y + edge)]
                                        + np.random.uniform(-0.01, 0.01, (150, edge, edge)) * ma)
                            aug_mask = mask[:, x : (x + edge), y : (y + edge)] | np.random.randint(0, 1, (150, edge, edge))
                            
                            flag = False #break the loop when you have a meaningful crop
                            break

                    # After having  11x11 croped sample, get another crop considering 
                    # the minimum edge length: (min_edge,min_edge)
                    if flag: 
                        max_edge = np.max(sh)
                        min_edge = np.min(sh)  # AUGMENT BY SHAPE
                        edge = min_edge  # np.random.randint(16, min_edge)
                        x = np.random.randint(sh[0] + 1 - edge)
                        y = np.random.randint(sh[1] + 1 - edge)
                        aug_data = (data[:, x : (x + edge), y : (y + edge)]
                                    + np.random.uniform(-0.001, 0.001, (150, edge, edge)) * ma)
                        aug_mask = mask[:, x : (x + edge), y : (y + edge)] | np.random.randint(0, 1, (150, edge, edge))

                    aug_datalist.append(aug_data)
                    aug_masklist.append(aug_mask)
                    aug_labellist.append(
                        labels[idx, :]
                        + labels[idx, :] * np.random.uniform(-0.001, 0.001, 4)
                    )

    # do pre-augmentation only for training data
    if is_train: 
        return (datalist,
                masklist,
                labels,
                aug_datalist,
                aug_masklist,
                np.array(aug_labellist))
    else:
        return datalist, masklist


def load_gt(file_path: str):
    """Load labels for train set from the ground truth file.
    Args:
        file_path (str): Path to the ground truth .csv file.
    Returns:
        [type]: 2D numpy array with soil properties levels
    """
    gt_file = pd.read_csv(file_path)
    labels = gt_file[["P", "K", "Mg", "pH"]].values / LABEL_MAXS  # normalize ground-truth between 0-1
    
    return labels

# %%
# Please be sure that the directory and file locations are given correctly in your own system
train_data_dir = '/kaggle/working/train_data/train_data'
test_data_dir=  '/kaggle/working/test_data'
gt_data_path = '/kaggle/working/train_data/train_gt.csv'

# Loading training raw data
X_train, M_train, y_train, X_aug_train, M_aug_train, y_aug_train = load_data(train_data_dir, 
                                                                             gt_data_path, 
                                                                             is_train=True, 
                                                                             augment_constant=AUGMENT_CONSTANT_KNN)
# Loading test raw data
X_test, M_test = load_data(test_data_dir, 
                           gt_file_path=None, 
                           is_train=False)

print(f"Train data size: {len(X_train)}")
print(f"Train aug data size: {len(X_aug_train)}")
print(f"Test data size: {len(X_test)}")
# Out:
# Loading training data ..:   0%|          | 0/1732 [00:00<?, ?it/s]
# Loading augmentation 1 ..:   0%|          | 0/1732 [00:00<?, ?it/s]
# Loading test data ..:   0%|          | 0/1154 [00:00<?, ?it/s]
# Train data size: 1732
# Train aug data size: 1732
# Test data size: 1154

# %%
def preprocess(data_list, mask_list, is_for_KNN=False): 
    """Extract high-level features from the raw field data.

    Args:
        data_list: Directory to either train or test set
        mask_list: File path for the ground truth labels (expected CVS file)
        is_for_KNN: Binary flag for determining if the features are generated for KNN (TRUE) or Random Forest (FALSE)
    Returns:
        [type]: Tuple of lists composed of (features , field size) pairs for each field, 
                where field size will be used performance analysis.
    """
        
    def _shape_pad(data):
        # This sub-function makes padding to have square fields sizes.
        # Not mandatory but eliminates the risk of calculation error in singular value decomposition,
        # padding by warping also improves the performance slightly.
        max_edge = np.max(image.shape[1:])
        shape = (max_edge, max_edge)
        padded = np.pad(data,((0, 0), (0, (shape[0] - data.shape[1])), (0, (shape[1] - data.shape[2]))),"wrap")
        return padded
    
    filtering = SpectralCurveFiltering()
    w1 = pywt.Wavelet("sym3")
    w2 = pywt.Wavelet("dmey")

    processed_data = []
    average_edge = []

    for idx, (data, mask) in enumerate(
        tqdm(
            zip(data_list, mask_list),
            total=len(data_list),
            position=0,
            leave=True,
            desc="INFO: Preprocessing data ...",
        )
    ):
        data = data / 2210   # max-max=5419 mean-max=2210
        m = 1 - mask.astype(int)
        image = data * m

        average_edge.append((image.shape[1] + image.shape[2]) / 2)
        image = _shape_pad(image)

        s = np.linalg.svd(image, full_matrices=False, compute_uv=False)
        s0 = s[:, 0]  
        s1 = s[:, 1]  
        s2 = s[:, 2] 
        s3 = s[:, 3]  
        s4 = s[:, 4]   
        dXds1 = s0 / (s1 + np.finfo(float).eps)


        data = np.ma.MaskedArray(data, mask)
        arr = filtering(data)

        cA0, cD0 = pywt.dwt(arr, wavelet=w2, mode="constant")
        cAx, cDx = pywt.dwt(cA0[12:92], wavelet=w2, mode="constant")
        cAy, cDy = pywt.dwt(cAx[15:55], wavelet=w2, mode="constant")
        cAz, cDz = pywt.dwt(cAy[15:35], wavelet=w2, mode="constant")
        cAw2 = np.concatenate((cA0[12:92], cAx[15:55], cAy[15:35], cAz[15:25]), -1)
        cDw2 = np.concatenate((cD0[12:92], cDx[15:55], cDy[15:35], cDz[15:25]), -1)

        cA0, cD0 = pywt.dwt(arr, wavelet=w1, mode="constant")
        cAx, cDx = pywt.dwt(cA0[1:-1], wavelet=w1, mode="constant")
        cAy, cDy = pywt.dwt(cAx[1:-1], wavelet=w1, mode="constant")
        cAz, cDz = pywt.dwt(cAy[1:-1], wavelet=w1, mode="constant")
        cAw1 = np.concatenate((cA0, cAx, cAy, cAz), -1)
        cDw1 = np.concatenate((cD0, cDx, cDy, cDz), -1)

        dXdl = np.gradient(arr, axis=0)
        d2Xdl2 = np.gradient(dXdl, axis=0)
        d3Xdl3 = np.gradient(d2Xdl2, axis=0)


        fft = np.fft.fft(arr)
        real = np.real(fft)
        imag = np.imag(fft)
        ffts = np.fft.fft(s0)
        reals = np.real(ffts)
        imags = np.imag(ffts)

        # The best Feature combination for Random Forest based regression
        out_rf = np.concatenate(
            [
                arr,
                dXdl,
                d2Xdl2,
                d3Xdl3,
                dXds1,
                s0,
                s1,
                s2,
                s3,
                s4,
                real,
                imag,
                reals,
                imags,
                cAw1,
                cAw2,
            ],
            -1,
        )
        
        # The best Feature combination for KNN based regression
        out_knn = np.concatenate(
            [
                arr,
                dXdl,
                d2Xdl2,
                d3Xdl3,
                s0,
                s1,
                s2,
                s3,
                s4,
                real,
                imag,

            ],
            -1,
        )
        
      
        if is_for_KNN:
            processed_data.append(out_knn)
        else:
            processed_data.append(out_rf)

    return np.array(processed_data), np.array(average_edge)



class SpectralCurveFiltering: # Default class provided by the challenge organizers
    """
    Create a histogram (a spectral curve) of a 3D cube, using the merge_function
    to aggregate all pixels within one band. The return array will have
    the shape of [CHANNELS_COUNT]
    """

    def __init__(self, merge_function=np.mean):
        self.merge_function = merge_function

    def __call__(self, sample: np.ndarray):
        return self.merge_function(sample, axis=(1, 2))

# %%
# preprocessed data for random forest traninig and testing
X_tr_processed_RF, avg_edge_train = preprocess(X_train, M_train, is_for_KNN=False)
X_aug_processed_RF, avg_edge_train_aug_RF = preprocess(X_aug_train[:len(X_train)*AUGMENT_CONSTANT_RF], M_aug_train[:len(X_train)*AUGMENT_CONSTANT_RF], is_for_KNN=False)
X_te_processed_RF, avg_edge_test = preprocess(X_test, M_test, is_for_KNN=False)

# preprocessed data for KNN traninig and testing
#X_tr_processed_KNN, avg_edge_train = preprocess(X_train, M_train, is_for_KNN=True)
#X_aug_processed_KNN, avg_edge_train_aug_KNN = preprocess(X_aug_train, M_aug_train,is_for_KNN=True)
#X_te_processed_KNN, avg_edge_test = preprocess(X_test, M_test, is_for_KNN=True)
# Out:
# INFO: Preprocessing data ...:   0%|          | 0/1732 [00:00<?, ?it/s]
# INFO: Preprocessing data ...:   0%|          | 0/1732 [00:00<?, ?it/s]
# INFO: Preprocessing data ...:   0%|          | 0/1154 [00:00<?, ?it/s]

# %%
# Select set of labels 
y_train_col = y_train[:, COL_IX]  
y_aug_train_col = y_aug_train[:len(y_train_col)*AUGMENT_CONSTANT_RF, COL_IX]
np.shape(y_aug_train_col)
# Out:
# (1732, 4)

# %%
# Merge original data with the augmented data on training set
concatente_var= np.concatenate((X_tr_processed_RF, X_aug_processed_RF), axis=0)
concatente_target = np.concatenate((y_train_col, y_aug_train_col), axis=0)
print(np.shape(concatente_var))
print(np.shape(concatente_target))
concatente_target
# Out:
# (3464, 2400)
# (3464, 4)
# array([[ 45.1       , 188.        , 179.        ,   7.2       ],
#        [ 44.8       , 205.        , 188.        ,   7.        ],
#        [ 44.4       , 207.        , 145.        ,   6.8       ],
#        ...,
#        [ 39.38728567, 179.98346239, 122.05096731,   6.495499  ],
#        [ 37.26517913, 161.93779433, 127.06955715,   6.49893802],
#        [ 29.49152673, 146.09600566, 132.90885945,   6.30248392]])

# %%
# Create a DataFrame with dummy column names
num_rows, num_cols =concatente_target.shape
#dummy_columns = [f'feat{i+1}' for i in range(num_cols)]
dummy_columns = ["P", "K", "Mg", "pH"]
y = pd.DataFrame(concatente_target, columns=dummy_columns)
# Now, 'train' is a DataFrame with dummy column names
y
# Out:
#               P           K          Mg        pH
# 0     45.100000  188.000000  179.000000  7.200000
# 1     44.800000  205.000000  188.000000  7.000000
# 2     44.400000  207.000000  145.000000  6.800000
# 3     46.500000  204.000000  143.000000  6.800000
# 4     52.000000  212.000000  167.000000  6.700000
# ...         ...         ...         ...       ...
# 3459  40.819368  132.953408  132.096370  6.201042
# 3460  42.742518  192.121235  125.964054  6.504712
# 3461  39.387286  179.983462  122.050967  6.495499
# 3462  37.265179  161.937794  127.069557  6.498938
# 3463  29.491527  146.096006  132.908859  6.302484
#
# [3464 rows x 4 columns]

# %%
# Create a DataFrame with dummy column names
num_rows, num_cols =concatente_var.shape
dummy_columns = [f'feat{i+1}' for i in range(num_cols)]
train = pd.DataFrame(concatente_var, columns=dummy_columns)
# Now, 'train' is a DataFrame with dummy column names
train
# Out:
#          feat1     feat2     feat3     feat4     feat5     feat6     feat7  \
# 0     0.203683  0.203992  0.202177  0.205636  0.210894  0.220505  0.226073
# 1     0.250603  0.249785  0.246786  0.250632  0.255035  0.265170  0.270217
# 2     0.191200  0.189831  0.187725  0.191629  0.196252  0.205140  0.209914
# 3     0.275959  0.276271  0.273568  0.278322  0.284468  0.296392  0.303449
# 4     0.182765  0.181889  0.179319  0.182695  0.186605  0.195498  0.200748
# ...        ...       ...       ...       ...       ...       ...       ...
# 3459  0.165413  0.165501  0.163484  0.167268  0.171699  0.180410  0.185604
# 3460  0.205924  0.206554  0.204983  0.209049  0.214850  0.224855  0.231180
# 3461  0.172906  0.173411  0.171933  0.175537  0.180699  0.189676  0.195400
# 3462  0.161537  0.161873  0.160385  0.164104  0.168783  0.177496  0.182867
# 3463  0.172316  0.172262  0.170219  0.174087  0.178574  0.187493  0.192773
#
#          feat8     feat9    feat10  ...  feat2391  feat2392  feat2393  \
# 0     0.227012  0.228581  0.230678  ...  0.805311  0.936756  1.290456
# 1     0.269648  0.269498  0.270211  ...  0.992393  1.105412  1.483055
# 2     0.210256  0.210999  0.211794  ...  0.756372  0.862336  1.140623
# 3     0.305312  0.308380  0.311888  ...  1.090404  1.272584  1.779799
# 4     0.201549  0.202935  0.204745  ...  0.721746  0.836694  1.217127
# ...        ...       ...       ...  ...       ...       ...       ...
# 3459  0.186594  0.188374  0.190428  ...  0.652480  0.777262  1.134233
# 3460  0.232533  0.234535  0.237170  ...  0.812914  0.965804  1.380149
# 3461  0.196652  0.198448  0.200822  ...  0.681913  0.818926  1.195245
# 3462  0.184015  0.185860  0.188004  ...  0.636854  0.766575  1.115399
# 3463  0.193672  0.195390  0.197331  ...  0.679972  0.804987  1.161038
#
#       feat2394  feat2395  feat2396  feat2397  feat2398  feat2399  feat2400
# 0     1.626534  1.777969  2.094892  2.382082  2.567942  2.697733  2.733829
# 1     1.721859  1.699395  2.483675  4.277375  4.606743  4.764096  4.809254
# 2     1.386935  1.473936  1.671600  1.852783  2.015047  2.058019  2.104777
# 3     2.184225  2.368559  2.711463  2.792593  3.004298  3.125400  3.193575
# 4     1.562283  1.710942  2.026881  2.311239  2.532482  2.615472  2.613160
# ...        ...       ...       ...       ...       ...       ...       ...
# 3459  1.490317  1.612101  1.845058  2.080594  2.260498  2.348053  2.364815
# 3460  1.795328  1.943117  2.221792  2.517689  2.723448  2.864458  2.936748
# 3461  1.568797  1.691405  1.928360  2.202616  2.378541  2.494439  2.529544
# 3462  1.457031  1.573237  1.804493  2.087973  2.270355  2.377441  2.403942
# 3463  1.515220  1.641954  1.883946  2.138303  2.331902  2.427664  2.446671
#
# [3464 rows x 2400 columns]

# %%
train2=pd.concat([train,y],axis=1)
train2['sample_index']=train2.index
train2
# Out:
#          feat1     feat2     feat3     feat4     feat5     feat6     feat7  \
# 0     0.203683  0.203992  0.202177  0.205636  0.210894  0.220505  0.226073
# 1     0.250603  0.249785  0.246786  0.250632  0.255035  0.265170  0.270217
# 2     0.191200  0.189831  0.187725  0.191629  0.196252  0.205140  0.209914
# 3     0.275959  0.276271  0.273568  0.278322  0.284468  0.296392  0.303449
# 4     0.182765  0.181889  0.179319  0.182695  0.186605  0.195498  0.200748
# ...        ...       ...       ...       ...       ...       ...       ...
# 3459  0.165413  0.165501  0.163484  0.167268  0.171699  0.180410  0.185604
# 3460  0.205924  0.206554  0.204983  0.209049  0.214850  0.224855  0.231180
# 3461  0.172906  0.173411  0.171933  0.175537  0.180699  0.189676  0.195400
# 3462  0.161537  0.161873  0.160385  0.164104  0.168783  0.177496  0.182867
# 3463  0.172316  0.172262  0.170219  0.174087  0.178574  0.187493  0.192773
#
#          feat8     feat9    feat10  ...  feat2396  feat2397  feat2398  \
# 0     0.227012  0.228581  0.230678  ...  2.094892  2.382082  2.567942
# 1     0.269648  0.269498  0.270211  ...  2.483675  4.277375  4.606743
# 2     0.210256  0.210999  0.211794  ...  1.671600  1.852783  2.015047
# 3     0.305312  0.308380  0.311888  ...  2.711463  2.792593  3.004298
# 4     0.201549  0.202935  0.204745  ...  2.026881  2.311239  2.532482
# ...        ...       ...       ...  ...       ...       ...       ...
# 3459  0.186594  0.188374  0.190428  ...  1.845058  2.080594  2.260498
# 3460  0.232533  0.234535  0.237170  ...  2.221792  2.517689  2.723448
# 3461  0.196652  0.198448  0.200822  ...  1.928360  2.202616  2.378541
# 3462  0.184015  0.185860  0.188004  ...  1.804493  2.087973  2.270355
# 3463  0.193672  0.195390  0.197331  ...  1.883946  2.138303  2.331902
#
#       feat2399  feat2400          P           K          Mg        pH  \
# 0     2.697733  2.733829  45.100000  188.000000  179.000000  7.200000
# 1     4.764096  4.809254  44.800000  205.000000  188.000000  7.000000
# 2     2.058019  2.104777  44.400000  207.000000  145.000000  6.800000
# 3     3.125400  3.193575  46.500000  204.000000  143.000000  6.800000
# 4     2.615472  2.613160  52.000000  212.000000  167.000000  6.700000
# ...        ...       ...        ...         ...         ...       ...
# 3459  2.348053  2.364815  40.819368  132.953408  132.096370  6.201042
# 3460  2.864458  2.936748  42.742518  192.121235  125.964054  6.504712
# 3461  2.494439  2.529544  39.387286  179.983462  122.050967  6.495499
# 3462  2.377441  2.403942  37.265179  161.937794  127.069557  6.498938
# 3463  2.427664  2.446671  29.491527  146.096006  132.908859  6.302484
#
#       sample_index
# 0                0
# 1                1
# 2                2
# 3                3
# 4                4
# ...            ...
# 3459          3459
# 3460          3460
# 3461          3461
# 3462          3462
# 3463          3463
#
# [3464 rows x 2405 columns]

# %%
"""gt_df = pd.read_csv(gt_data_path)
print(gt_df.shape)
gt_df.head()"""
# Out:
# 'gt_df = pd.read_csv(gt_data_path)\nprint(gt_df.shape)\ngt_df.head()'

# %%
gt_p=train2[['sample_index','P']]
gt_K=train2[['sample_index','K']]
gt_Mg=train2[['sample_index','Mg']]
gt_pH=train2[['sample_index','pH']]
gt_pH.head()
# Out:
#    sample_index   pH
# 0             0  7.2
# 1             1  7.0
# 2             2  6.8
# 3             3  6.8
# 4             4  6.7

# %%
def reshape_dataframe(dataframe, id_vars, var_name, value_name):
    # Melt the DataFrame to reshape it
    melted = pd.melt(dataframe, id_vars=id_vars, var_name=var_name, value_name=value_name)

    # You can create the final 'sample_index' column here if needed
    melted['Target'] = melted['sample_index'].astype(str) + '_' + melted['Target']

    # Drop the 'index' column
    melted.drop('sample_index', axis=1, inplace=True)

    return melted

# Example usage
gt_p = reshape_dataframe(gt_p, id_vars=['sample_index'], var_name='Target', value_name='Value')
gt_K = reshape_dataframe(gt_K, id_vars=['sample_index'], var_name='Target', value_name='Value')
gt_Mg = reshape_dataframe(gt_Mg, id_vars=['sample_index'], var_name='Target', value_name='Value')
gt_pH = reshape_dataframe(gt_pH, id_vars=['sample_index'], var_name='Target', value_name='Value')
print(gt_pH.shape)
gt_pH.head()
# Out:
# (3464, 2)
#   Target  Value
# 0   0_pH    7.2
# 1   1_pH    7.0
# 2   2_pH    6.8
# 3   3_pH    6.8
# 4   4_pH    6.7

# %%
# Example usage
gt_p = pd.concat([gt_p,train2],axis=1)
gt_K = pd.concat([gt_K,train2],axis=1)
gt_Mg = pd.concat([gt_Mg,train2],axis=1)
gt_pH = pd.concat([gt_pH,train2],axis=1)
train = pd.concat([gt_p,gt_K,gt_Mg,gt_pH],axis=0)
train.to_csv('train.csv',index=False)
print(train.shape)
train.head()
# Out:
# (13856, 2407)
#   Target  Value     feat1     feat2     feat3     feat4     feat5     feat6  \
# 0    0_P   45.1  0.203683  0.203992  0.202177  0.205636  0.210894  0.220505
# 1    1_P   44.8  0.250603  0.249785  0.246786  0.250632  0.255035  0.265170
# 2    2_P   44.4  0.191200  0.189831  0.187725  0.191629  0.196252  0.205140
# 3    3_P   46.5  0.275959  0.276271  0.273568  0.278322  0.284468  0.296392
# 4    4_P   52.0  0.182765  0.181889  0.179319  0.182695  0.186605  0.195498
#
#       feat7     feat8  ...  feat2396  feat2397  feat2398  feat2399  feat2400  \
# 0  0.226073  0.227012  ...  2.094892  2.382082  2.567942  2.697733  2.733829
# 1  0.270217  0.269648  ...  2.483675  4.277375  4.606743  4.764096  4.809254
# 2  0.209914  0.210256  ...  1.671600  1.852783  2.015047  2.058019  2.104777
# 3  0.303449  0.305312  ...  2.711463  2.792593  3.004298  3.125400  3.193575
# 4  0.200748  0.201549  ...  2.026881  2.311239  2.532482  2.615472  2.613160
#
#       P      K     Mg   pH  sample_index
# 0  45.1  188.0  179.0  7.2             0
# 1  44.8  205.0  188.0  7.0             1
# 2  44.4  207.0  145.0  6.8             2
# 3  46.5  204.0  143.0  6.8             3
# 4  52.0  212.0  167.0  6.7             4
#
# [5 rows x 2407 columns]

# %%
np.shape(X_te_processed_RF)
# Out:
# (1154, 2400)

# %%
np.shape(X_tr_processed_RF)
# Out:
# (1732, 2400)

# %%
# Create a DataFrame with dummy column names
num_rows, num_cols = X_te_processed_RF.shape
dummy_columns = [f'feat{i+1}' for i in range(num_cols)]
test = pd.DataFrame(X_te_processed_RF, columns=dummy_columns)
# Assuming you have a DataFrame 'test', create the 'Target' column
test_P=test.copy()
test_K=test.copy()
test_Mg=test.copy()
test_PH=test.copy()

test_P['Target'] = [f'{i}_P' for i in range(len(test_P))]
test_P['mean_norm'] = 70.3026558891455
#70.3026558891455,227.9885103926097,159.28123556581986,6.782719399538106
test_K['Target'] = [f'{i}_K' for i in range(len(test_K))]
test_K['mean_norm'] = 227.9885103926097

test_Mg['Target'] = [f'{i}_Mg' for i in range(len(test_Mg))]
test_Mg['mean_norm'] = 159.28123556581986

test_PH['Target'] = [f'{i}_pH' for i in range(len(test_PH))]
test_PH['mean_norm'] = 6.782719399538106

test=pd.concat([test_P,test_K,test_Mg,test_PH],axis=0)

# Now, your 'Target' column in the test DataFrame will have values like '0_P', '1_P', '2_P', and so on.
print(test.shape)
test.to_csv('test.csv',index=False)

# Now, 'train' is a DataFrame with dummy column names
test
# Out:
# (4616, 2402)
#          feat1     feat2     feat3     feat4     feat5     feat6     feat7  \
# 0     0.173565  0.171952  0.168504  0.170999  0.173946  0.181525  0.185026
# 1     0.202796  0.201845  0.199020  0.202500  0.206132  0.214863  0.219335
# 2     0.164810  0.163459  0.161074  0.163151  0.166365  0.173361  0.176534
# 3     0.196746  0.195933  0.192789  0.195939  0.199449  0.207141  0.210958
# 4     0.265508  0.266124  0.264145  0.268839  0.274781  0.286389  0.293448
# ...        ...       ...       ...       ...       ...       ...       ...
# 1149  0.201331  0.201670  0.199746  0.204116  0.209300  0.219236  0.225269
# 1150  0.187588  0.188071  0.186565  0.190504  0.195775  0.205280  0.211257
# 1151  0.246595  0.247139  0.245130  0.250370  0.256538  0.268103  0.275224
# 1152  0.195533  0.196011  0.194421  0.198574  0.203896  0.213583  0.219580
# 1153  0.162502  0.162253  0.160069  0.163695  0.167853  0.176373  0.181360
#
#          feat8     feat9    feat10  ...  feat2393  feat2394  feat2395  \
# 0     0.184056  0.183710  0.183698  ...  1.174493  1.269823  1.064050
# 1     0.218668  0.218889  0.219440  ...  1.248479  1.495482  1.494265
# 2     0.175363  0.174817  0.174266  ...  1.169714  1.269090  0.967839
# 3     0.209670  0.209044  0.208800  ...  1.135058  1.346569  1.292224
# 4     0.294926  0.297448  0.300688  ...  1.668053  2.016291  2.163232
# ...        ...       ...       ...  ...       ...       ...       ...
# 1149  0.226503  0.228633  0.231030  ...  1.355050  1.761454  1.890163
# 1150  0.212602  0.214667  0.217173  ...  1.292950  1.703421  1.837563
# 1151  0.276892  0.279748  0.283008  ...  1.646616  2.134732  2.322334
# 1152  0.220892  0.222968  0.225395  ...  1.307993  1.691528  1.829480
# 1153  0.182229  0.183950  0.185722  ...  1.095332  1.429914  1.542066
#
#       feat2396  feat2397  feat2398  feat2399  feat2400   Target  mean_norm
# 0     1.963784  4.521961  5.065660  5.246762  5.330273      0_P  70.302656
# 1     2.381440  4.517328  4.982208  5.206562  5.262480      1_P  70.302656
# 2     2.094396  5.501404  6.153006  6.340413  6.413906      2_P  70.302656
# 3     2.551541  5.902475  6.501725  6.768157  6.804711      3_P  70.302656
# 4     2.443648  2.528219  2.715599  2.822610  2.819261      4_P  70.302656
# ...        ...       ...       ...       ...       ...      ...        ...
# 1149  2.161619  2.482829  2.687889  2.808897  2.861287  1149_pH   6.782719
# 1150  2.098486  2.399257  2.591536  2.715855  2.773716  1150_pH   6.782719
# 1151  2.661394  2.926015  3.165880  3.297552  3.393916  1151_pH   6.782719
# 1152  2.100164  2.407549  2.618703  2.759835  2.830244  1152_pH   6.782719
# 1153  1.766857  2.017786  2.205045  2.280156  2.291676  1153_pH   6.782719
#
# [4616 rows x 2402 columns]
